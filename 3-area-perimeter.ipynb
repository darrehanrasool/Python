# %%
## area of rectangle using python code 
## in python everthing is object.
## by default input funtion returns string type
length=int(input("enter the length buddy:"))
breadth=int(input("enter the breadth buddy:"))
print(type(length))
print(type(breadth))
## memory location address.
print(id(length))
print(id(breadth))
area=length*breadth
perimeter=2*(length+breadth)
print(f'are is equal to {area} and perimeter is equal to {perimeter}')
# Out:
# <class 'int'>
# <class 'int'>
# 4333987200
# 4333987200
# are is equal to 4 and perimeter is equal to 8

# %%
## area and perimeter of triangle right angle
height=int(input("Enter the height buddy :"))
base=int(input("Enter the base buddy :"))
hypotinues=7
area=0.5*(base*height)
perimeter=height+base+hypotinues
print(f'are is equal {area}, perimeter is equal {perimeter}')
# Out:
# are is equal 7.0, perimeter is equal 16

# %%
## area and perimeter of square
side=int(input("enter the value for side buddy :"))
area =side**2
perimeter=4*side
print(f'are of square is {area}, perimeter of square is {perimeter}')
# Out:
# are of square is 4, perimeter of square is 8

# %%
## area and perimeter of circle
import math
radius=int(input("enter the radius buddy :"))
area=math.pi*(radius**2)
perimeter=2*math.pi*radius
print(f'area is equal to {area} , perimeter is equal to {perimeter}')
# Out:
# area is equal to 28.274333882308138 , perimeter is equal to 18.84955592153876

# %%
## area and perimeter of trapizium 
a=int(input("enter the value of a buddy :"))
b=int(input("enter the value of a buddy :"))
c=int(input("enter the value of a buddy :"))
d=int(input("enter the value of a buddy :"))
h=int(input("enter the value of h buddy :"))
area=0.5*(a+b)*h
print(f'area is equal to {area} , perimeter is equal to {perimeter}')
# Out:
# area is equal to 7.5 , perimeter is equal to 18.84955592153876

# %%
# Surface Area of a Cuboid

length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))
height = float(input("Enter height: "))

surface_area = 2 * (length * breadth + breadth * height + length * height)

print("Surface Area of Cuboid:", surface_area)
# Out:
# Surface Area of Cuboid: 16.0

# %%
## kilometer to miles 
kilometer=int(input('enter the value in kilometers buddy :'))
miles=kilometer*0.621371
print(f' kilometers to miles conversion : {miles}')
# Out:
#  kilometers to miles conversion : 34.796776

# %%
## displacement
u=int(input("eneter the initial velocity :"))
v=int(input("eneter the final velocity :"))
displacement=(v**2-u**2)/(2*a)
print
