# %%
## type conversion or type casting
## int
a=16.59
b=True
c=False
d='0b1010'
e='0xA'
f='123'
g='abc' ## here it will show an error we need to proivde valid number string
h=3+1j  ## error complex number not supported
print(int(a))
print(int(b))
print(int(c))
print(int(d,2))
print(int(e,16))
print(int(f))
# Out:
# 16
# 1
# 0
# 10
# 10
# 123

# %%
## type conversion or type casting
## float
a=16
b=True
c=False
d='0b1010'
print(float(a))
print(float(b))
print(float(c))
# Out:
# 16.0
# 1.0
# 0.0

# %%
## type conversion or type casting
## boolean 
## everthing is true except False, 0 , empty string
a=11
b=True
c=False
d='0b1010'
e=''
f=0
g='False' ##
h=False   ##
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
print(bool(f))
print(bool(g))
print(bool(h))
# Out:
# True
# True
# False
# True
# False
# False
# True
# False

# %%
## type conversion or type casting
## complex 
a=10
b=-12.5
c=True
d=False
e='2+1j'
print(complex(a))
print(complex(b))
print(complex(c))
print(complex(d))
print(complex(e))
# Out:
# (10+0j)
# (-12.5+0j)
# (1+0j)
# 0j
# (2+1j)

# %%
## type conversion or type casting
## string
a=10
b=-12
c=-1.2E3
d=False
e=3+2j
print(str(a))
print(str(b))
print(str(c))
print(str(d))
print(str(e))
# Out:
# 10
# -12
# -1200.0
# False
# (3+2j)
