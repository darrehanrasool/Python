# %%
## Area of Rectangle
length=10
breadth=15
## in python everthing is object.
print(type(length))
print(type(breadth))
## memory location address.
print(id(length))
print(id(breadth))
area=length*breadth
print('area = ',area)
# Out:
# <class 'int'>
# <class 'int'>
# 4315637376
# 4315637536
# area =  150
