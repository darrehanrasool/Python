# %%
## using three variables.
a=1
b=2
temp=a
a=b
b=temp
print("swap result : ",a,b)
# Out:
# swap result :  2 1

# %%
## using two variables. 
a=1
b=2
a=a+b
b=a-b
a=a-b
print("swap result : ",a,b)
# Out:
# swap result :  2 1

# %%
## using XOR operation.
a=1
b=2
a=a^b
b=a^b
a=a^b
print("swap result : ",a,b)
# Out:
# swap result :  2 1
