# %%
## a simple program example ie bill amount
price=[1,2,3,4,5,6,7,7,8,8,8,]
quantity=[1,2,3,4,5,6,7,8,9,0,4]
total=0
for i in range(len(price)):
    total=total+price[i]+quantity[i]
    
print("the total bill amount is buddy : ",total)
# Out:
# the total bill amount is buddy :  108
