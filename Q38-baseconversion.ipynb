# %%
## base conversion funtions
s_1=bin(10)   ## binary
s_2=oct(10)   ## octal
s_3=hex(10)   ## hexadecimal
s_4=int("10") ## decimal
s_5=bin(True) ## boolean
s_6=bin(2.8)  ## float  it will show an error here because its expecting integer only
print("output : ",s_1,s_2,s_3,s_4,s_5)
print(type(s_1))
print(type(s_2))
print(type(s_3))
print(type(s_4))
print(type(s_5))
# Out:
# output :  0b1010 0o12 0xa 10 0b1
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
