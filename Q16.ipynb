# %% [markdown]
# # Question 16
#
# ## Question
# Convert polar coordinates to Cartesian coordinates.
#
# ## Explanation
# Enter radius and angle in degrees. The coordinates are obtained using cosine and sine.
#
# ## How to run
# Run the code cell and enter the requested values when prompted.

# %%
import math

radius = float(input('Enter radius: '))
angle_degrees = float(input('Enter angle in degrees: '))
angle_radians = math.radians(angle_degrees)

## x = r*cos(theta), y = r*sin(theta); math trig functions use radians.
x = radius * math.cos(angle_radians)
y = radius * math.sin(angle_radians)

print(f'Cartesian coordinates: ({x:.2f}, {y:.2f})')
